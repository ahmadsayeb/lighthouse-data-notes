# %%
import pandas as pd
from pandas import json_normalize
import json
from pprint import pprint

# %%
url = "https://raw.githubusercontent.com/chrisalbon/simulated_datasets/master/data.json"
first_json = pd.read_json(url)
first_json.head(30)
# Out:
#     integer            datetime  category
# 0         5 2015-01-01 00:00:00         0
# 1         5 2015-01-01 00:00:01         0
# 2         9 2015-01-01 00:00:02         0
# 3         6 2015-01-01 00:00:03         0
# 4         6 2015-01-01 00:00:04         0
# 5         9 2015-01-01 00:00:05         0
# 6         7 2015-01-01 00:00:06         0
# 7         1 2015-01-01 00:00:07         0
# 8         6 2015-01-01 00:00:08         0
# 9         9 2015-01-01 00:00:09         0
# 10        5 2015-01-01 00:00:10         0
# 11        5 2015-01-01 00:00:11         0
# 12        8 2015-01-01 00:00:12         0
# 13        9 2015-01-01 00:00:13         0
# 14        8 2015-01-01 00:00:14         0
# 15        8 2015-01-01 00:00:15         0
# 16        2 2015-01-01 00:00:16         0
# 17        1 2015-01-01 00:00:17         0
# 18        4 2015-01-01 00:00:18         0
# 19        8 2015-01-01 00:00:19         0
# 20        9 2015-01-01 00:00:20         0
# 21        5 2015-01-01 00:00:21         0
# 22        4 2015-01-01 00:00:22         0
# 23        8 2015-01-01 00:00:23         0
# 24        6 2015-01-01 00:00:24         0
# 25        4 2015-01-01 00:00:25         0
# 26        5 2015-01-01 00:00:26         0
# 27        6 2015-01-01 00:00:27         0
# 28        3 2015-01-01 00:00:28         0
# 29        7 2015-01-01 00:00:29         0

# %%
first_json.to_json("json_columns.json",orient = "columns")
first_json.to_json("json_index.json", orient = "index")

# %%
df = pd.read_json("nested.json")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-2464ca5b0b2a> in <module>
# ----> 1 df = pd.read_json("nested.json")
#
# ~\anaconda3\envs\bootcamp\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     197                 else:
#     198                     kwargs[new_arg_name] = new_arg_value
# --> 199             return func(*args, **kwargs)
#     200
#     201         return cast(F, wrapper)
#
# ~\anaconda3\envs\bootcamp\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 296             return func(*args, **kwargs)
#     297
#     298         return wrapper
#
# ~\anaconda3\envs\bootcamp\lib\site-packages\pandas\io\json\_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression, nrows)
#     616         return json_reader
#     617
# --> 618     result = json_reader.read()
#     619     if should_close:
#     620         filepath_or_buffer.close()
#
# ~\anaconda3\envs\bootcamp\lib\site-packages\pandas\io\json\_json.py in read(self)
#     753                 obj = self._get_object_parser(self._combine_lines(data))
#     754         else:
# --> 755             obj = self._get_object_parser(self.data)
#     756         self.close()
#     757         return obj
#
# ~\anaconda3\envs\bootcamp\lib\site-packages\pandas\io\json\_json.py in _get_object_parser(self, json)
#     775         obj = None
#     776         if typ == "frame":
# --> 777             obj = FrameParser(json, **kwargs).parse()
#     778
#     779         if typ == "series" or obj is None:
#
# ~\anaconda3\envs\bootcamp\lib\site-packages\pandas\io\json\_json.py in parse(self)
#     884
#     885         else:
# --> 886             self._parse_no_numpy()
#     887
#     888         if self.obj is None:
#
# ~\anaconda3\envs\bootcamp\lib\site-packages\pandas\io\json\_json.py in _parse_no_numpy(self)
#    1116
#    1117         if orient == "columns":
# -> 1118             self.obj = DataFrame(
#    1119                 loads(json, precise_float=self.precise_float), dtype=None
#    1120             )
#
# ~\anaconda3\envs\bootcamp\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     466
#     467         elif isinstance(data, dict):
# --> 468             mgr = init_dict(data, index, columns, dtype=dtype)
#     469         elif isinstance(data, ma.MaskedArray):
#     470             import numpy.ma.mrecords as mrecords
#
# ~\anaconda3\envs\bootcamp\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     281             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     282         ]
# --> 283     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     284
#     285
#
# ~\anaconda3\envs\bootcamp\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity)
#      76         # figure out the index, if necessary
#      77         if index is None:
# ---> 78             index = extract_index(arrays)
#      79         else:
#      80             index = ensure_index(index)
#
# ~\anaconda3\envs\bootcamp\lib\site-packages\pandas\core\internals\construction.py in extract_index(data)
#     395             lengths = list(set(raw_lengths))
#     396             if len(lengths) > 1:
# --> 397                 raise ValueError("arrays must all be same length")
#     398
#     399             if have_dicts:
#
# ValueError: arrays must all be same length

# %%
with open('nested.json') as f:
    nested_json = json.load(f)
pprint(nested_json)
# Out:
# {'article': [{'author': 'Allen',
#               'edition': 'first',
#               'id': '01',
#               'language': 'JSON'},
#              {'author': 'Aditya Sharma',
#               'edition': 'second',
#               'id': '02',
#               'language': 'Python'}],
#  'blog': [{'URL': 'datacamp.com', 'name': 'Datacamp'}]}

# %%
json_normalize(nested_json)
# Out:
#                                              article  \
# 0  [{'id': '01', 'language': 'JSON', 'edition': '...
#
#                                             blog
# 0  [{'name': 'Datacamp', 'URL': 'datacamp.com'}]

# %%
blog = json_normalize(nested_json, record_path = 'blog')

# %%
blog.head()
# Out:
#        name           URL
# 0  Datacamp  datacamp.com

# %%
data = [{"state": "Florida", 
        "shortname": "FL",
        "info": {"governor": "Rick Scott"},
        "counties": [{"name": "Dade", "population": 12345},
                     {"name": "Broward", "population": 40000},
                     {"name": "Palm Beach", "population": 60000}]},
       {"state": "Ohio",
        "shortname": "OH",
        "info": {"governor": "John Kasich"},
        "counties": [{"name": "Summit", "population": 1234},
                     {"name": "Cuyahoga", "population": 1337}]}]

# %%
json_normalize(data = data, record_path='counties')
# Out:
#          name  population
# 0        Dade       12345
# 1     Broward       40000
# 2  Palm Beach       60000
# 3      Summit        1234
# 4    Cuyahoga        1337

# %%
json_normalize(data = data, record_path='counties', meta=['state','shortname', ['info','governor']])
# Out:
#          name  population    state shortname info.governor
# 0        Dade       12345  Florida        FL    Rick Scott
# 1     Broward       40000  Florida        FL    Rick Scott
# 2  Palm Beach       60000  Florida        FL    Rick Scott
# 3      Summit        1234     Ohio        OH   John Kasich
# 4    Cuyahoga        1337     Ohio        OH   John Kasich
